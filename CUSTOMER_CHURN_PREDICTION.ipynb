# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthpachori/customer-churn-prediction/blob/main/CUSTOMER_CHURN_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv('/content/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df=pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df['Gender_Male']=df['Gender_Male'].replace({True:1,False:0})
df['Geography_Spain']=df['Geography_Spain'].replace({True:1,False:0})
df['Geography_Germany']=df['Geography_Germany'].replace({True:1,False:0})

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geography_Germany  Geography_Spain  Gender_Male
# 0                  0                0            0
# 1                  0                1            0
# 2                  0                0            0
# 3                  0                0            0
# 4                  0                1            0

# %%
df.drop(['RowNumber','CustomerId','Surname'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['Exited']),df['Exited'],random_state=20,test_size=0.2)

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(11,activation='sigmoid',input_dim=11))
model.add(Dense(11,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              12 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(x_train,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3824 - loss: 0.7542 - val_accuracy: 0.8012 - val_loss: 0.5345
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7869 - loss: 0.5293 - val_accuracy: 0.8012 - val_loss: 0.4852
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7925 - loss: 0.4938 - val_accuracy: 0.8012 - val_loss: 0.4726
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7795 - loss: 0.4999 - val_accuracy: 0.8012 - val_loss: 0.4620
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7835 - loss: 0.4843 - val_accuracy: 0.8012 - val_loss: 0.4525
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7861 - loss: 0.4754 - val_accuracy: 0.8012 - val_loss: 0.4431
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7954 - loss: 0.4517 - val_accuracy: 0.8012 - val_loss: 0.4345
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.4465 - val_accuracy: 0.8081 - val_loss: 0.4268
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7937 - loss: 0.4446 - val_accuracy: 0.8156 - val_loss: 0.4197
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8038 - loss: 0.4336 - val_accuracy: 0.8181 - val_loss: 0.4154
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8336 - loss: 0.3860 - val_accuracy: 0.8587 - val_loss: 0.3579
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8350 - loss: 0.3881 - val_accuracy: 0.8556 - val_loss: 0.3567
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8411 - loss: 0.3822 - val_accuracy: 0.8625 - val_loss: 0.3558
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8467 - loss: 0.3746 - val_accuracy: 0.8644 - val_loss: 0.3563
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8356 - loss: 0.3771 - val_accuracy: 0.8625 - val_loss: 0.3532
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8416 - loss: 0.3742 - val_accuracy: 0.8631 - val_loss: 0.3521
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8511 - loss: 0.3611 - val_accuracy: 0.8644 - val_loss: 0.3521
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8460 - loss: 0.3751 - val_accuracy: 0.8619 - val_loss: 0.3506
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.3558 - val_accuracy: 0.8656 - val_loss: 0.3509
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8530 - loss: 0.3605 - val_accuracy: 0.8600 - val_loss: 0.3488
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8490 - loss: 0.3651 - val_accuracy: 0.8662 - val_loss: 0.3485
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8476 - loss: 0.3707 - val_accuracy: 0.8656 - val_loss: 0.3478
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8460 - loss: 0.3701 - val_accuracy: 0.8600 - val_loss: 0.3465
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8523 - loss: 0.3579 - val_accuracy: 0.8662 - val_loss: 0.3465
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8449 - loss: 0.3732 - val_accuracy: 0.8687 - val_loss: 0.3465
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.3609 - val_accuracy: 0.8662 - val_loss: 0.3447
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.3639 - val_accuracy: 0.8637 - val_loss: 0.3434
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8541 - loss: 0.3540 - val_accuracy: 0.8675 - val_loss: 0.3437
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8449 - loss: 0.3719 - val_accuracy: 0.8644 - val_loss: 0.3426
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8513 - loss: 0.3562 - val_accuracy: 0.8662 - val_loss: 0.3420
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8466 - loss: 0.3677 - val_accuracy: 0.8650 - val_loss: 0.3417
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8481 - loss: 0.3623 - val_accuracy: 0.8687 - val_loss: 0.3438
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8584 - loss: 0.3499 - val_accuracy: 0.8700 - val_loss: 0.3425
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.3592 - val_accuracy: 0.8700 - val_loss: 0.3404
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8592 - loss: 0.3544 - val_accuracy: 0.8725 - val_loss: 0.3405
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8458 - loss: 0.3698 - val_accuracy: 0.8637 - val_loss: 0.3399
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3619 - val_accuracy: 0.8700 - val_loss: 0.3387
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3628 - val_accuracy: 0.8700 - val_loss: 0.3381
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8550 - loss: 0.3639 - val_accuracy: 0.8712 - val_loss: 0.3386
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8527 - loss: 0.3610 - val_accuracy: 0.8681 - val_loss: 0.3374
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8574 - loss: 0.3532 - val_accuracy: 0.8706 - val_loss: 0.3375
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8537 - loss: 0.3605 - val_accuracy: 0.8694 - val_loss: 0.3368
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8501 - loss: 0.3639 - val_accuracy: 0.8719 - val_loss: 0.3374
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8590 - loss: 0.3556 - val_accuracy: 0.8725 - val_loss: 0.3373
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8528 - loss: 0.3558 - val_accuracy: 0.8694 - val_loss: 0.3358
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8606 - loss: 0.3460 - val_accuracy: 0.8712 - val_loss: 0.3380
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8528 - loss: 0.3584 - val_accuracy: 0.8687 - val_loss: 0.3351
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.3647 - val_accuracy: 0.8700 - val_loss: 0.3346
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8577 - loss: 0.3437 - val_accuracy: 0.8737 - val_loss: 0.3354
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8550 - loss: 0.3549 - val_accuracy: 0.8712 - val_loss: 0.3345
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.3657 - val_accuracy: 0.8719 - val_loss: 0.3344
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3470 - val_accuracy: 0.8712 - val_loss: 0.3340
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8606 - loss: 0.3445 - val_accuracy: 0.8731 - val_loss: 0.3337
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8606 - loss: 0.3482 - val_accuracy: 0.8725 - val_loss: 0.3334
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8571 - loss: 0.3556 - val_accuracy: 0.8744 - val_loss: 0.3333
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8498 - loss: 0.3612 - val_accuracy: 0.8725 - val_loss: 0.3329
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8507 - loss: 0.3570 - val_accuracy: 0.8719 - val_loss: 0.3320
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8546 - loss: 0.3515 - val_accuracy: 0.8712 - val_loss: 0.3329
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8645 - loss: 0.3359 - val_accuracy: 0.8725 - val_loss: 0.3325
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8524 - loss: 0.3572 - val_accuracy: 0.8737 - val_loss: 0.3319
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8522 - loss: 0.3574 - val_accuracy: 0.8719 - val_loss: 0.3322
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8572 - loss: 0.3467 - val_accuracy: 0.8731 - val_loss: 0.3316
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8583 - loss: 0.3421 - val_accuracy: 0.8719 - val_loss: 0.3306
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8603 - loss: 0.3440 - val_accuracy: 0.8719 - val_loss: 0.3305
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8586 - loss: 0.3452 - val_accuracy: 0.8725 - val_loss: 0.3305
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8609 - loss: 0.3535 - val_accuracy: 0.8737 - val_loss: 0.3310
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8585 - loss: 0.3435 - val_accuracy: 0.8744 - val_loss: 0.3294
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8578 - loss: 0.3458 - val_accuracy: 0.8737 - val_loss: 0.3303
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8550 - loss: 0.3451 - val_accuracy: 0.8737 - val_loss: 0.3306

# %%
y_pred = model.predict(x_test)
y_test.shape
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (2000,)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
y_pred.shape
# Out:
# (2000,)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8115

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
